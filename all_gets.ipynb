# %%
import requests

headers = {
    'Accept': 'application/ld+json',
}

def get_all_resource(resource_type):
    query_resource = f'  ?s rdf:type {resource_type} .'
    data = {
        'query': 'PREFIX xml: <http://www.w3.org/XML/1998/namespace>'
                 'PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>'
                 'PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>'
                 'PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>'
                 'PREFIX dc: <http://purl.org/dc/terms/>'
                 'PREFIX mc: <https://w3id.org/mint/modelCatalog#>'
                 'CONSTRUCT {'
                 '?s ?o ?p '
                 '}'
                 'WHERE {'
                 f'{query_resource}'
                 '?s ?o ?p'
                 '}'
    }

    return requests.post('http://ontosoft.isi.edu:3030/ds/query', headers=headers, data=data)

# %%
types = ['mc:ModelConfiguration', "mc:CAG", 'mc:DataSet', 'mc:Model', "mc:ModelConfiguration", "mc:ModelVersion", "mc:Parameter", "mc:Process",  "mc:TimeInterval", "mc:Unit"]

# %%
get_all_resource(t).json())
# Out:
# {'@graph': [{'@id': 'mint:DSSAT_cfg_simple', '@type': 'mc:ModelConfiguration', 'hasContainer': 'mint:mintproject/dssat:latest', 'hasImplementationScriptLocation': 'https://raw.githubusercontent.com/KnowledgeCaptureAndDiscovery/MINT-WorkflowDomain/master/WINGSWorkflowComponents/DSSAT_config_simple/run', 'description': 'DSSAT simple working configuration with explicit outputs', 'label': 'DSSAT simple configuration', 'hasCAG': 'mint:DSSAT_cfg_simple_CAG', 'hasComponentLocation': 'https://github.com/KnowledgeCaptureAndDiscovery/MINT-WorkflowDomain/raw/master/WINGSWorkflowComponents/DSSAT_config_simple/DSSAT_config_simple.zip', 'hasInput': ['mint:DSSAT_sol', 'mint:DSSAT_simulationFile', 'mint:DSSAT_weatherFile'], 'hasOutput': 'mint:DSSAT_summary', 'hasTimeInterval': 'mint:DSSAT_cfg_simple_TI'}, {'@id': 'mint:FLDAS2WGEN_cfg', '@type': 'mc:ModelConfiguration'}, {'@id': 'mint:WGEN2FLDAS_cfg', '@type': 'mc:ModelConfiguration'}, {'@id': 'mint:clim_comp_P', '@type': 'mc:ModelConfiguration', 'hasContainer': 'mint:mintproject/base-ubuntu18:latest', 'hasImplementationScriptLocation': 'https://raw.githubusercontent.com/KnowledgeCaptureAndDiscovery/MINT-WorkflowDomain/master/WINGSWorkflowComponents/clim_comp/run', 'description': 'This configuration accepts the precipitation input from FLDAS dataset', 'label': 'ClimComp configuration for precipitation', 'hasComponentLocation': 'https://github.com/KnowledgeCaptureAndDiscovery/MINT-WorkflowDomain/raw/master/WINGSWorkflowComponents/clim_comp/clim_comp.zip', 'hasInput': 'mint:climcomp_FLDAS_P', 'hasOutput': ['mint:climcomp_P_climatology', 'mint:climcomp_P_summary'], 'hasParameter': ['mint:climcomp_flagP', 'mint:climcomp_max_month', 'mint:climcomp_min_lat', 'mint:climcomp_min_month', 'mint:climcomp_year', 'mint:climcomp_datasource', 'mint:climcomp_max_lon', 'mint:climcomp_max_lat', 'mint:climcomp_min_lon'], 'hasTimeInterval': 'mint:climcomp_0.0.2_P_cfg_TI'}, {'@id': 'mint:clim_comp_T', '@type': 'mc:ModelConfiguration', 'hasContainer': 'mint:mintproject/base-ubuntu18:latest', 'hasImplementationScriptLocation': 'https://raw.githubusercontent.com/KnowledgeCaptureAndDiscovery/MINT-WorkflowDomain/master/WINGSWorkflowComponents/clim_comp/run', 'description': 'This configuration accepts the temperature input from FLDAS data', 'label': 'ClimComp configuration for temperature', 'hasComponentLocation': 'https://github.com/KnowledgeCaptureAndDiscovery/MINT-WorkflowDomain/raw/master/WINGSWorkflowComponents/clim_comp/clim_comp.zip', 'hasInput': 'mint:climcomp_FLDAS_T', 'hasOutput': ['mint:climcomp_T_summary', 'mint:climcomp_T_climatology'], 'hasParameter': ['mint:climcomp_datasource', 'mint:climcomp_flagP_T', 'mint:climcomp_min_month', 'mint:climcomp_year', 'mint:climcomp_min_lat', 'mint:climcomp_max_month', 'mint:climcomp_max_lat', 'mint:climcomp_max_lon', 'mint:climcomp_min_lon'], 'hasTimeInterval': 'mint:climcomp_0.0.2_T_cfg_TI'}, {'@id': 'mint:cycles', '@type': 'mc:ModelConfiguration', 'hasContainer': 'mint:mintproject/cycles:latest', 'hasImplementationScriptLocation': 'https://raw.githubusercontent.com/KnowledgeCaptureAndDiscovery/MINT-WorkflowDomain/master/WINGSWorkflowComponents/cycles/cycles/run', 'description': 'Cycles configuration to run the model with PIHM. Prepared to run on Singularity', 'label': 'Cycles configuration', 'hasCAG': ['mint:cycles_cfg_complex_CAG', 'mint:cycles_cfg_simple_CAG'], 'hasComponentLocation': 'https://github.com/KnowledgeCaptureAndDiscovery/MINT-WorkflowDomain/raw/master/WINGSWorkflowComponents/cycles/cycles.zip', 'hasInput': ['mint:cycles_reinit', 'mint:cycles_weather', 'mint:cycles_config', 'mint:cycles_soil'], 'hasOutput': ['mint:cycles_somF', 'mint:cycles_weatherOutput', 'mint:cycles_season', 'mint:cycles_nitrogen', 'mint:cycles_water', 'mint:cycles_seasonConfig', 'mint:cycles_summary', 'mint:cycles_soilProfile', 'mint:cyles_crop'], 'hasParameter': ['mint:cycles_planting-day-2-duration', 'mint:cycles_planting-day-1-duration', 'mint:cycles_planting-day-2', 'mint:cycles_pl ...
# {'@graph': [{'@id': 'mint:DSSAT_cfg_simple_CAG', '@type': 'mc:CAG'}, {'@id': 'mint:cycles_cfg_complex_CAG', '@type': 'mc:CAG', 'label': 'CAG for Cycles representing a more complex version of the variables and processes of the model', 'hasPart': ['mint:cycles_ws', 'mint:cycles_swc', 'mint:cycles_soil_evapr', 'mint:cycles_bd', 'mint:cycles_smc', 'mint:cycles_soil_evap', 'mint:cycles_net_mineraliz', 'mint:cycles_transpiration', 'mint:cycles_pp', 'mint:cycles_hn', 'mint:cycles_dz', 'mint:cycles_percolation', 'mint:cycles_som', 'mint:cycles_cn', 'mint:cycles_infiltration', 'mint:cycles_cropGrowth', 'mint:cycles_tn', 'mint:cycles_tx', 'mint:cycles_mineralization', 'mint:cycles_clay', 'mint:cycles_silt', 'mint:cycles_sr', 'mint:cycles_grain_yield', 'mint:cycles_n_stress', 'mint:cycles_slope', 'mint:cycles_hx', 'mint:cycles_layer', 'mint:cycles_rv']}, {'@id': 'mint:cycles_cfg_simple_CAG', '@type': 'mc:CAG', 'label': 'CAG for Cycles with the most important variables in the model', 'hasPart': ['mint:cycles_swc', 'mint:cycles_sr', 'mint:cycles_hn', 'mint:cycles_ws', 'mint:cycles_grain_yield', 'mint:cycles_pp', 'mint:cycles_tx', 'mint:cycles_hx', 'mint:cycles_transpiration', 'mint:cycles_tn', 'mint:cycles_cropGrowth']}, {'@id': 'mint:cycles_cfg_simple_CAG_process', '@type': 'mc:CAG', 'label': 'CAG for Cycles simple configuration with processes', 'hasPart': ['mint:biomassgrowth', 'mint:management', 'mint:Ntransport', 'mint:Nuptake', 'mint:Nmineralizationandimmobalization', 'mint:humification', 'mint:cycles_precipitation', 'mint:cycles_transpiration', 'mint:respiration', 'mint:cycles_solarradiation']}, {'@id': 'mint:dssat_cfg_fk_CAG', '@type': 'mc:CAG', 'label': 'CAG for DSSAT with fake configuration to emulate Cycles'}, {'@id': 'mint:dssat_cfg_simple_CAG', '@type': 'mc:CAG', 'label': 'CAG for DSSAT simple configuration with explicit outputs'}, {'@id': 'mint:economic_aggregate_crop_supply_CAG_process', '@type': 'mc:CAG', 'label': 'CAG for Economic model for aggregate crop supply response model processes for the country of South Sudan configuration', 'hasPart': ['mint:fertilizer_use', 'mint:land_use', 'mint:crop_prices', 'mint:fertilizer_prices', 'mint:crop_yield_elasticity', 'mint:crop_supply', 'mint:crop_yield']}, {'@id': 'mint:economic_aggregate_crop_supply_CAG_variables', '@type': 'mc:CAG', 'label': 'CAG for Economic model for aggregate crop supply response model variables for the country of South Sudan configuration', 'hasPart': ['mint:econ_land_area', 'mint:econ_xbar2', 'mint:econ_p', 'mint:econ_obsyield', 'mint:econ_c2', 'mint:econ_eta', 'mint:econ_xbar1', 'mint:econ_ybarN', 'mint:econ_ybar', 'mint:econ_production', 'mint:econ_c1']}, {'@id': 'mint:kimetrica_land_use_cfg_simple_CAG', '@type': 'mc:CAG', 'label': 'CAG for Kimetrica land use simple configuration', 'hasPart': ['mint:econ_land_area', 'mint:econ_obsyield']}, {'@id': 'mint:pihm_cfg_simple2_CAG', '@type': 'mc:CAG', 'label': 'CAG for PIHM simple configuration with additional input variables', 'hasPart': ['mint:precipitation', 'mint:infiltration', 'mint:runoff', 'mint:transpiration', 'mint:evaporation', 'mint:solarradiation']}, {'@id': 'mint:pihm_cfg_simple_CAG', '@type': 'mc:CAG', 'label': 'CAG for PIHM simple configuration', 'hasPart': ['mint:precipitation', 'mint:infiltration', 'mint:runoff', 'mint:transpiration', 'mint:evaporation', 'mint:solarradiation']}, {'@id': 'mint:topoflow_cfg_fk_CAG', '@type': 'mc:CAG', 'label': 'CAG for TopoFlow with fake configuration to emulate PIHM'}, {'@id': 'mint:topoflow_cfg_simple_CAG', '@type': 'mc:CAG', 'label': 'CAG forTopoFlow with basic configuration'}], '@context': {'label': {'@id': 'http://www.w3.org/2000/01/rdf-schema#label'}, 'hasPart': {'@id': 'https://w3id.org/mint/modelCatalog#hasPart', '@type': '@id'}, 'ccut': 'https://www.w3id.org/mint/ccut#', 'mint': 'https://w3id.org/mint/instance/', 'qudtp': 'http://qudt.org/1.1/schema/qudt#', 'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#', 'owl': 'http://www.w3.org/2002/07/owl#', 'xml' ...
# {'@context': {'ccut': 'https://www.w3id.org/mint/ccut#', 'mint': 'https://w3id.org/mint/instance/', 'qudtp': 'http://qudt.org/1.1/schema/qudt#', 'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#', 'owl': 'http://www.w3.org/2002/07/owl#', 'xml': 'http://www.w3.org/XML/1998/namespace', 'mc': 'https://w3id.org/mint/modelCatalog#', 'xsd': 'http://www.w3.org/2001/XMLSchema#', 'rdfs': 'http://www.w3.org/2000/01/rdf-schema#', 'dc': 'http://purl.org/dc/terms/'}}
# {'@graph': [{'@id': 'mint:CYCLES', '@type': ['mc:TheoryBasedModel', 'mc:Model'], 'hasDocumentation': 'https://plantscience.psu.edu/research/labs/kemanian/models-and-tools/cycles', 'hasSoftwareVersion': 'mint:cycles_0.8.0_alpha', 'description': 'Cycles simulates the productivity and the water-carbon and nitrogen balance of soil-crop systems subject to climate conditions and a large array of management constraints', 'label': 'Cycles', 'hasAssumption': 'The simulation unit in Cycles is a field with a single soil (soil file) that is layered (user defined number of layers) exposed to a daily weather (weather file) and subject to operations (operations file) that control soil properties; vegetation properties (crop file) and surface residue properties. Variables in weather file are considered rigid forcings. Surface conditions do not alter air temperature or moisture. Soil is connected to the residues; aboveground living biomass; air; and radiation from the atmosphere; and with the bottom of the profile. There is no lateral water or solutes movement within the soil profile. When running stand alone; runoff and percolation water simply leaves the simulation unit. Vegetation can be composed of monocultures (single species) or multiple species. The parameters describing each plant of the community are described in the crop file. The operations file allows multiple types of interventions organized as tillage; fertilization; and planting events. Operations like kill crop are part of tillage. To enable coupling with other models; Cycles can be set to replace (re-initialize) internally calculated variable with external inputs. For example; infiltration can be an input from the PIHM model; soil moisture can be reset based on observations or data from other models. This flexibility extends to all state variables. Re-initialization algorithm can break the mass balance and is not recommended unless the goal override mass or energy balance concerns.', 'hasModelCategory': 'Agriculture'}, {'@id': 'mint:ClimComp', '@type': ['mc:EmpiricalModel', 'mc:Model'], 'hasDocumentation': 'https://github.com/khider/ClimComp', 'hasSoftwareVersion': 'mint:ClimComp_0.0.2', 'description': 'ClimComp is a Python routine for comparing the seasonal prediction with the average climatology', 'label': 'ClimComp', 'hasModelCategory': 'Weather'}, {'@id': 'mint:DSSAT', '@type': ['mc:TheoryBasedModel', 'mc:Model'], 'hasDocumentation': 'https://dssat.net', 'hasSoftwareVersion': 'mint:DSSAT_4.7', 'description': 'The Decision Support System for Agrotechnology Transfer (DSSAT) comprises dynamic crop growth simulation model for over 40 crops. The model simulates growth; development; and yield as a function of the soil-plant-atmosphere dynamics.', 'label': 'DSSAT', 'hasModelCategory': 'Agriculture'}, {'@id': 'mint:ECONOMIC_AGGREGATE_CROP_SUPPLY', '@type': ['mc:TheoryBasedModel', 'mc:Model'], 'hasSoftwareVersion': 'mint:EACS_2.0', 'description': 'The EACS describes the aggregate crop supply response model for the country of South Sudan', 'label': 'Aggregate crop supply response model', 'hasAssumption': 'This is a regional-scale aggregate model of agricultural supply for a specified set of crops (cassava; groundnuts; maize; sesame seed; and sorghum). The model calibrates the parameters of a constant elasticity of substitution (CES) production function and linear cost function using the positive mathematical programming (PMP) method. Calibration relies on observed data on agricultural input use (land and fertilizer) and crop yields. Markets are assumed complete.', 'hasModelCategory': 'Economic'}, {'@id': 'mint:KIMETRICA_LAND_USE', '@type': 'mc:Model', 'hasSoftwareVersion': 'mint:kimetrica_0.0', 'description': 'The Kimetrica model simulates land use.', 'label': 'Kimetrica land use model', 'hasModelCategory': 'Land Use'}, {'@id': 'mint:MODFLOW', '@type': ['mc:TheoryBasedModel', 'mc:Model'], 'hasDocumentation': 'https://water.usgs.gov/ogw/modflow/', 'hasSoftwareVersion': ['mint:modflow ...
# {'@graph': [{'@id': 'mint:DSSAT_cfg_simple', '@type': 'mc:ModelConfiguration', 'hasContainer': 'mint:mintproject/dssat:latest', 'hasImplementationScriptLocation': 'https://raw.githubusercontent.com/KnowledgeCaptureAndDiscovery/MINT-WorkflowDomain/master/WINGSWorkflowComponents/DSSAT_config_simple/run', 'description': 'DSSAT simple working configuration with explicit outputs', 'label': 'DSSAT simple configuration', 'hasCAG': 'mint:DSSAT_cfg_simple_CAG', 'hasComponentLocation': 'https://github.com/KnowledgeCaptureAndDiscovery/MINT-WorkflowDomain/raw/master/WINGSWorkflowComponents/DSSAT_config_simple/DSSAT_config_simple.zip', 'hasInput': ['mint:DSSAT_sol', 'mint:DSSAT_simulationFile', 'mint:DSSAT_weatherFile'], 'hasOutput': 'mint:DSSAT_summary', 'hasTimeInterval': 'mint:DSSAT_cfg_simple_TI'}, {'@id': 'mint:FLDAS2WGEN_cfg', '@type': 'mc:ModelConfiguration'}, {'@id': 'mint:WGEN2FLDAS_cfg', '@type': 'mc:ModelConfiguration'}, {'@id': 'mint:clim_comp_P', '@type': 'mc:ModelConfiguration', 'hasContainer': 'mint:mintproject/base-ubuntu18:latest', 'hasImplementationScriptLocation': 'https://raw.githubusercontent.com/KnowledgeCaptureAndDiscovery/MINT-WorkflowDomain/master/WINGSWorkflowComponents/clim_comp/run', 'description': 'This configuration accepts the precipitation input from FLDAS dataset', 'label': 'ClimComp configuration for precipitation', 'hasComponentLocation': 'https://github.com/KnowledgeCaptureAndDiscovery/MINT-WorkflowDomain/raw/master/WINGSWorkflowComponents/clim_comp/clim_comp.zip', 'hasInput': 'mint:climcomp_FLDAS_P', 'hasOutput': ['mint:climcomp_P_climatology', 'mint:climcomp_P_summary'], 'hasParameter': ['mint:climcomp_flagP', 'mint:climcomp_max_month', 'mint:climcomp_min_lat', 'mint:climcomp_min_month', 'mint:climcomp_year', 'mint:climcomp_datasource', 'mint:climcomp_max_lon', 'mint:climcomp_max_lat', 'mint:climcomp_min_lon'], 'hasTimeInterval': 'mint:climcomp_0.0.2_P_cfg_TI'}, {'@id': 'mint:clim_comp_T', '@type': 'mc:ModelConfiguration', 'hasContainer': 'mint:mintproject/base-ubuntu18:latest', 'hasImplementationScriptLocation': 'https://raw.githubusercontent.com/KnowledgeCaptureAndDiscovery/MINT-WorkflowDomain/master/WINGSWorkflowComponents/clim_comp/run', 'description': 'This configuration accepts the temperature input from FLDAS data', 'label': 'ClimComp configuration for temperature', 'hasComponentLocation': 'https://github.com/KnowledgeCaptureAndDiscovery/MINT-WorkflowDomain/raw/master/WINGSWorkflowComponents/clim_comp/clim_comp.zip', 'hasInput': 'mint:climcomp_FLDAS_T', 'hasOutput': ['mint:climcomp_T_summary', 'mint:climcomp_T_climatology'], 'hasParameter': ['mint:climcomp_datasource', 'mint:climcomp_flagP_T', 'mint:climcomp_min_month', 'mint:climcomp_year', 'mint:climcomp_min_lat', 'mint:climcomp_max_month', 'mint:climcomp_max_lat', 'mint:climcomp_max_lon', 'mint:climcomp_min_lon'], 'hasTimeInterval': 'mint:climcomp_0.0.2_T_cfg_TI'}, {'@id': 'mint:cycles', '@type': 'mc:ModelConfiguration', 'hasContainer': 'mint:mintproject/cycles:latest', 'hasImplementationScriptLocation': 'https://raw.githubusercontent.com/KnowledgeCaptureAndDiscovery/MINT-WorkflowDomain/master/WINGSWorkflowComponents/cycles/cycles/run', 'description': 'Cycles configuration to run the model with PIHM. Prepared to run on Singularity', 'label': 'Cycles configuration', 'hasCAG': ['mint:cycles_cfg_complex_CAG', 'mint:cycles_cfg_simple_CAG'], 'hasComponentLocation': 'https://github.com/KnowledgeCaptureAndDiscovery/MINT-WorkflowDomain/raw/master/WINGSWorkflowComponents/cycles/cycles.zip', 'hasInput': ['mint:cycles_reinit', 'mint:cycles_weather', 'mint:cycles_config', 'mint:cycles_soil'], 'hasOutput': ['mint:cycles_somF', 'mint:cycles_weatherOutput', 'mint:cycles_season', 'mint:cycles_nitrogen', 'mint:cycles_water', 'mint:cycles_seasonConfig', 'mint:cycles_summary', 'mint:cycles_soilProfile', 'mint:cyles_crop'], 'hasParameter': ['mint:cycles_planting-day-2-duration', 'mint:cycles_planting-day-1-duration', 'mint:cycles_planting-day-2', 'mint:cycles_pl ...
# {'@graph': [{'@id': 'mint:ClimComp_0.0.2', '@type': ['http://ontosoft.org/software#SoftwareVersion', 'mc:ModelVersion'], 'hasVersionId': '0.0.2', 'label': 'climcompv0.0.2', 'hasConfiguration': ['mint:clim_comp_P', 'mint:clim_comp_T']}, {'@id': 'mint:DSSAT_4.7', '@type': ['http://ontosoft.org/software#SoftwareVersion', 'mc:ModelVersion'], 'hasVersionId': '4.7', 'label': 'DSSAT v4.7', 'hasConfiguration': 'mint:DSSAT_cfg_simple'}, {'@id': 'mint:EACS_2.0', '@type': ['http://ontosoft.org/software#SoftwareVersion', 'mc:ModelVersion'], 'hasVersionId': '2', 'label': 'EACS 2.0', 'hasConfiguration': 'mint:economic'}, {'@id': 'mint:cycles_0.8.0_alpha', '@type': ['http://ontosoft.org/software#SoftwareVersion', 'mc:ModelVersion'], 'hasVersionId': '0.8.0', 'label': 'Cycles v0.8.0 alpha', 'hasConfiguration': ['mint:cycles_multiple_points', 'mint:cycles']}, {'@id': 'mint:kimetrica_0.0', '@type': ['http://ontosoft.org/software#SoftwareVersion', 'mc:ModelVersion'], 'hasVersionId': '0', 'label': 'Kimetrica lv0.o0', 'hasConfiguration': 'mint:kimetrica_land_use_cfg_simple'}, {'@id': 'mint:modflow_2005', '@type': ['http://ontosoft.org/software#SoftwareVersion', 'mc:ModelVersion'], 'hasVersionId': '2005', 'label': 'Modflow 2005', 'hasConfiguration': 'mint:modflow_2005_cfg'}, {'@id': 'mint:modflow_nwt', '@type': ['http://ontosoft.org/software#SoftwareVersion', 'mc:ModelVersion'], 'hasVersionId': 'nwt', 'label': 'Modflow NWT', 'hasConfiguration': 'mint:modflow_nwt_cfg'}, {'@id': 'mint:pihm_2.2', '@type': ['http://ontosoft.org/software#SoftwareVersion', 'mc:ModelVersion'], 'hasVersionId': '2.2', 'label': 'PIHM v2.2', 'hasConfiguration': 'mint:pihm'}, {'@id': 'mint:topoflow_3.5', '@type': ['http://ontosoft.org/software#SoftwareVersion', 'mc:ModelVersion'], 'hasVersionId': '3.5', 'label': 'Topoflow v3.5', 'hasConfiguration': 'mint:topoflow_cfg_simple'}, {'@id': 'mint:wgen_1.0.1', '@type': ['http://ontosoft.org/software#SoftwareVersion', 'mc:ModelVersion'], 'hasVersionId': '1.0.1', 'label': 'wgen v1.0.1', 'hasConfiguration': 'mint:weather_generator'}], '@context': {'hasVersionId': {'@id': 'http://ontosoft.org/software#hasVersionId'}, 'hasConfiguration': {'@id': 'https://w3id.org/mint/modelCatalog#hasConfiguration', '@type': '@id'}, 'label': {'@id': 'http://www.w3.org/2000/01/rdf-schema#label'}, 'ccut': 'https://www.w3id.org/mint/ccut#', 'mint': 'https://w3id.org/mint/instance/', 'qudtp': 'http://qudt.org/1.1/schema/qudt#', 'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#', 'owl': 'http://www.w3.org/2002/07/owl#', 'xml': 'http://www.w3.org/XML/1998/namespace', 'mc': 'https://w3id.org/mint/modelCatalog#', 'xsd': 'http://www.w3.org/2001/XMLSchema#', 'rdfs': 'http://www.w3.org/2000/01/rdf-schema#', 'dc': 'http://purl.org/dc/terms/'}}
# {'@graph': [{'@id': 'https://w3id.org/mint/instance/', '@type': 'mc:Parameter'}, {'@id': 'mint:climcomp_datasource', '@type': ['https://w3id.org/wings/export/MINT#DataSource', 'mc:Parameter'], 'description': 'dataset source', 'label': 'dataset_source', 'hasDataType': 'string', 'hasDefaultValue': 'FLDAS'}, {'@id': 'mint:climcomp_flagP', '@type': ['https://w3id.org/wings/export/MINT#FlagP', 'mc:Parameter'], 'description': 'flag P', 'label': 'flagP', 'hasDataType': 'string', 'hasDefaultValue': 'Rainf_f_tavg'}, {'@id': 'mint:climcomp_flagP_T', '@type': 'mc:Parameter'}, {'@id': 'mint:climcomp_max_lat', '@type': ['https://w3id.org/wings/export/MINT#MaxLatitude', 'mc:Parameter'], 'description': 'maximum latitude', 'label': 'max_lat', 'hasDataType': 'float', 'hasDefaultValue': '9.335303'}, {'@id': 'mint:climcomp_max_lon', '@type': ['https://w3id.org/wings/export/MINT#MaxLongitude', 'mc:Parameter'], 'description': 'maximum longitude', 'label': 'max_lon', 'hasDataType': 'float', 'hasDefaultValue': '27.74012'}, {'@id': 'mint:climcomp_max_month', '@type': ['https://w3id.org/wings/export/MINT#MaxMonth', 'mc:Parameter'], 'description': 'maximum month', 'label': 'max_month', 'hasDataType': 'float', 'hasDefaultValue': '8'}, {'@id': 'mint:climcomp_min_lat', '@type': ['https://w3id.org/wings/export/MINT#MinLatitude', 'mc:Parameter'], 'description': 'minimum latitude', 'label': 'min_lat', 'hasDataType': 'float', 'hasDefaultValue': '6.700375'}, {'@id': 'mint:climcomp_min_lon', '@type': ['https://w3id.org/wings/export/MINT#MinLongitude', 'mc:Parameter'], 'description': 'minimum longitude', 'label': 'min_lon', 'hasDataType': 'float', 'hasDefaultValue': '24.15235'}, {'@id': 'mint:climcomp_min_month', '@type': ['https://w3id.org/wings/export/MINT#MinMonth', 'mc:Parameter'], 'description': 'minimum month', 'label': 'min_month', 'hasDataType': 'float', 'hasDefaultValue': '6'}, {'@id': 'mint:climcomp_year', '@type': ['https://w3id.org/wings/export/MINT#ClimCompYear', 'mc:Parameter'], 'description': 'year', 'label': 'year', 'hasDataType': 'float', 'hasDefaultValue': '2017'}, {'@id': 'mint:cycles_planting-day-1', '@type': ['https://w3id.org/wings/export/MINT#CyclesPlantingDay1', 'mc:Parameter'], 'description': 'planting day 1', 'label': 'cycles_planting-day-1', 'hasDataType': 'int', 'hasDefaultValue': '100'}, {'@id': 'mint:cycles_planting-day-1-duration', '@type': ['https://w3id.org/wings/export/MINT#CyclesPlantingDay1Duration', 'mc:Parameter'], 'description': 'planting day 1 duration', 'label': 'cycles_planting-day-1-duration', 'hasDataType': 'int', 'hasDefaultValue': '10'}, {'@id': 'mint:cycles_planting-day-2', '@type': ['https://w3id.org/wings/export/MINT#CyclesPlantingDay2', 'mc:Parameter'], 'description': 'planting day 2', 'label': 'cycles_planting-day-2', 'hasDataType': 'int', 'hasDefaultValue': '225'}, {'@id': 'mint:cycles_planting-day-2-duration', '@type': ['https://w3id.org/wings/export/MINT#CyclesPlantingDay2Duration', 'mc:Parameter'], 'description': 'planting day 2 duration', 'label': 'cycles_planting-day-2-duration', 'hasDataType': 'int', 'hasDefaultValue': '10'}, {'@id': 'mint:cycles_to_crop_start-date', '@type': ['https://w3id.org/wings/export/MINT#StartDate', 'mc:Parameter'], 'label': 'start-date', 'hasDataType': 'string', 'hasDefaultValue': '2017-01-01'}, {'@id': 'mint:economic_to_vis_region_name', '@type': ['https://w3id.org/wings/export/MINT#RegionName', 'mc:Parameter'], 'label': 'region-name', 'hasDataType': 'string', 'hasDefaultValue': 'pg'}, {'@id': 'mint:economic_to_vis_start_date', '@type': ['https://w3id.org/wings/export/MINT#StartDate', 'mc:Parameter'], 'label': 'start-date', 'hasDataType': 'string', 'hasDefaultValue': '2017-01-01'}, {'@id': 'mint:fldas_to_pihm_end-date', '@type': ['https://w3id.org/wings/export/MINT#EndDate', 'mc:Parameter'], 'label': 'fldas_to_pihm_end-date', 'hasDataType': 'string', 'hasDefaultValue': '2017-12-31'}, {'@id': 'mint:fldas_to_pihm_start-date', '@type': ['https://w3id.org/wings/export/MINT#StartDate ...
# {'@graph': [{'@id': 'mint:Nmineralizationandimmobalization', '@type': 'mc:Process', 'label': 'N mineralization and immobalization', 'influences': 'mint:Ntransport'}, {'@id': 'mint:Ntransport', '@type': 'mc:Process', 'label': 'N transport'}, {'@id': 'mint:Nuptake', '@type': 'mc:Process', 'label': 'N uptake', 'influences': 'mint:Ntransport'}, {'@id': 'mint:biomassgrowth', '@type': 'mc:Process', 'label': 'biomass growth', 'influences': ['mint:respiration', 'mint:humification', 'mint:cycles_transpiration']}, {'@id': 'mint:crop_prices', '@type': 'mc:Process', 'label': 'crop prices', 'influences': ['mint:fertilizer_use', 'mint:land_use']}, {'@id': 'mint:crop_supply', '@type': 'mc:Process', 'label': 'crop supply'}, {'@id': 'mint:crop_yield', '@type': 'mc:Process', 'label': 'crop yield', 'influences': 'mint:crop_supply'}, {'@id': 'mint:crop_yield_elasticity', '@type': 'mc:Process', 'label': 'crop yield elasticity', 'influences': ['mint:fertilizer_use', 'mint:land_use', 'mint:crop_yield']}, {'@id': 'mint:cycles_cropGrowth', '@type': 'mc:Process', 'label': 'Crop growth', 'influences': 'mint:cycles_grain_yield'}, {'@id': 'mint:cycles_percolation', '@type': 'mc:Process', 'label': 'Percolation', 'influences': ['mint:cycles_avg_no3_leach', 'mint:cycles_nh4_leaching', 'mint:cycles_avg_nh4_leach', 'mint:cycles_no3_leaching']}, {'@id': 'mint:cycles_precipitation', '@type': ['mc:VariablePresentation', 'mc:Process'], 'description': 'Precipitation', 'label': ['PRECIPITATION', 'precipitation in cycles'], 'hasRelevanceLevel': '3', 'hasShortName': 'PRECIPITATION', 'hasStandardVariable': 'atmosphere_water__time_integral_of_precipitation_volume_flux', 'influences': 'mint:cycles_transpiration', 'usesUnit': 'mint:mmL'}, {'@id': 'mint:cycles_solarradiation', '@type': 'mc:Process', 'label': 'solar radiation in cycles', 'influences': ['mint:cycles_transpiration', 'mint:biomassgrowth']}, {'@id': 'mint:cycles_transpiration', '@type': ['mc:VariablePresentation', 'mc:Process'], 'description': 'Transpiration by the crop canopy.', 'label': ['transpiration in cycles', 'TRANSPIRATION'], 'hasRelevanceLevel': '1', 'hasShortName': 'TRANSPIRATION', 'hasStandardVariable': 'crop_canopy_water__volume-per-area_transpiration_rate', 'influences': ['mint:cycles_cropGrowth', 'mint:biomassgrowth', 'mint:Nuptake'], 'usesUnit': 'mint:mm_day_1L_T_1'}, {'@id': 'mint:evaporation', '@type': 'mc:Process', 'label': 'evaporation', 'influences': ['mint:infiltration', 'mint:runoff']}, {'@id': 'mint:fertilizer_prices', '@type': 'mc:Process', 'label': 'fertilizer prices', 'influences': ['mint:fertilizer_use', 'mint:land_use']}, {'@id': 'mint:fertilizer_use', '@type': 'mc:Process', 'label': 'fertilizer use', 'influences': ['mint:land_use', 'mint:crop_yield']}, {'@id': 'mint:humification', '@type': 'mc:Process', 'label': 'humification', 'influences': 'mint:Nmineralizationandimmobalization'}, {'@id': 'mint:infiltration', '@type': 'mc:Process', 'label': 'infiltration', 'influences': 'mint:runoff'}, {'@id': 'mint:land_use', '@type': 'mc:Process', 'label': 'land use', 'influences': ['mint:fertilizer_use', 'mint:crop_supply', 'mint:crop_yield']}, {'@id': 'mint:management', '@type': 'mc:Process', 'label': 'management', 'influences': 'mint:biomassgrowth'}, {'@id': 'mint:precipitation', '@type': 'mc:Process', 'label': 'precipitation', 'influences': ['mint:infiltration', 'mint:runoff']}, {'@id': 'mint:respiration', '@type': 'mc:Process', 'label': 'respiration', 'influences': 'mint:Nmineralizationandimmobalization'}, {'@id': 'mint:runoff', '@type': 'mc:Process', 'label': 'runoff'}, {'@id': 'mint:solarradiation', '@type': 'mc:Process', 'label': 'solar radiation', 'influences': ['mint:transpiration', 'mint:evaporation']}, {'@id': 'mint:transpiration', '@type': 'mc:Process', 'label': 'transpiration', 'influences': ['mint:infiltration', 'mint:runoff']}], '@context': {'influences': {'@id': 'https://w3id.org/mint/modelCatalog#influences', '@type': '@id'}, 'label': {'@id': 'http://www.w3.org/2000/01/rdf-sche ...
# {'@graph': [{'@id': 'mint:DSSAT_cfg_simple_TI', '@type': 'mc:TimeInterval'}, {'@id': 'mint:climcomp_0.0.2_P_cfg_TI', '@type': 'mc:TimeInterval', 'description': 'Time interval at which ClimComp outputs', 'label': 'ClimComp time interval', 'hasValue': '1', 'usesUnit': 'mint:yearT'}, {'@id': 'mint:climcomp_0.0.2_T_cfg_TI', '@type': 'mc:TimeInterval', 'description': 'Time interval at which ClimComp outputs', 'label': 'ClimComp time interval', 'hasValue': '1', 'usesUnit': 'mint:yearT'}, {'@id': 'mint:cycles_cfg_simple_TI', '@type': 'mc:TimeInterval', 'description': 'Time interval used in the Cycles simple configuration', 'label': 'Simple cycles time interval', 'hasValue': '1', 'usesUnit': 'mint:dayT'}, {'@id': 'mint:dssat_cfg_fk_TI', '@type': 'mc:TimeInterval', 'description': 'Time interval used in the  DSSAT with fake configuration to emulate Cycles', 'label': 'Simple dssat time interval'}, {'@id': 'mint:dssat_cfg_simple_TI', '@type': 'mc:TimeInterval', 'description': 'Time interval used in the DSSAT simple configuration', 'label': 'Simple dssat time interval'}, {'@id': 'mint:economic_aggregate_crop_supply_TI', '@type': 'mc:TimeInterval', 'description': 'Time interval used in the aggregate crop supply response model for the country of South Sudan configuration', 'label': 'Simple economic time interval', 'hasValue': '1', 'usesUnit': 'mint:yearT'}, {'@id': 'mint:kimetrica_land_use_cfg_simple_TI', '@type': 'mc:TimeInterval', 'description': 'Time interval used in the Kimetrica land use simple configuration', 'label': 'Simple kimetrica time interval'}, {'@id': 'mint:pihm_cfg_simple2_TI', '@type': 'mc:TimeInterval', 'description': 'Time interval used in the PIHM simple configuration with additional input variables', 'label': 'Simple PIHM time interval', 'hasValue': '1', 'usesUnit': 'mint:dayT'}, {'@id': 'mint:pihm_cfg_simple_TI', '@type': 'mc:TimeInterval', 'description': 'Time interval used in the PIHM simple configuration', 'label': 'Simple PIHM time interval', 'hasValue': '1', 'usesUnit': 'mint:dayT'}, {'@id': 'mint:topoflow_cfg_fk_TI', '@type': 'mc:TimeInterval', 'description': 'Time interval used in the TopoFlow with fake configuration to emulate PIHM', 'label': 'Simple topoflow time interval'}, {'@id': 'mint:topoflow_cfg_simple_TI', '@type': 'mc:TimeInterval', 'description': 'Time interval used in the TopoFlow with basic configuration', 'label': 'Simple topoflow time interval'}, {'@id': 'mint:wgen_1.0.1_cfg_timeinterval', '@type': 'mc:TimeInterval', 'description': 'Time interval used in WGEN basic configuration', 'label': 'WGEN time interval', 'hasValue': '1', 'usesUnit': 'mint:dayT'}], '@context': {'description': {'@id': 'http://purl.org/dc/terms/description'}, 'label': {'@id': 'http://www.w3.org/2000/01/rdf-schema#label'}, 'hasValue': {'@id': 'https://w3id.org/mint/modelCatalog#hasValue'}, 'usesUnit': {'@id': 'https://w3id.org/mint/modelCatalog#usesUnit', '@type': '@id'}, 'ccut': 'https://www.w3id.org/mint/ccut#', 'mint': 'https://w3id.org/mint/instance/', 'qudtp': 'http://qudt.org/1.1/schema/qudt#', 'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#', 'owl': 'http://www.w3.org/2002/07/owl#', 'xml': 'http://www.w3.org/XML/1998/namespace', 'mc': 'https://w3id.org/mint/modelCatalog#', 'xsd': 'http://www.w3.org/2001/XMLSchema#', 'rdfs': 'http://www.w3.org/2000/01/rdf-schema#', 'dc': 'http://purl.org/dc/terms/'}}
# {'@context': {'ccut': 'https://www.w3id.org/mint/ccut#', 'mint': 'https://w3id.org/mint/instance/', 'qudtp': 'http://qudt.org/1.1/schema/qudt#', 'rdf': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#', 'owl': 'http://www.w3.org/2002/07/owl#', 'xml': 'http://www.w3.org/XML/1998/namespace', 'mc': 'https://w3id.org/mint/modelCatalog#', 'xsd': 'http://www.w3.org/2001/XMLSchema#', 'rdfs': 'http://www.w3.org/2000/01/rdf-schema#', 'dc': 'http://purl.org/dc/terms/'}}
